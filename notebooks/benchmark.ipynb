# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# module hot reload
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# !! CHDIR to project directory
import os
os.chdir("/content/drive/MyDrive/PoseGraph/tgraphnet/src")
sys.path.append(os.path.abspath('/content/drive/MyDrive/PoseGraph/tgraphnet/src/'))
sys.path.append('/content/drive/MyDrive/PoseGraph/tgraphnet/src/features')

print(os.getcwd())
print(sys.path)
# Out:
# /content/drive/.shortcut-targets-by-id/17ykzHxgNFRVy8q3zg8wJUQxqgX-WEO1n/PoseGraph/tgraphnet/src
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/PoseGraph/tgraphnet/src', '/content/drive/MyDrive/PoseGraph/tgraphnet/src/features']

# %%
# %cd /content/drive/My Drive/PoseGraph/tgraphnet/src
# Out:
# /content

# %%
os.environ['PYTHONPATH'] += ":/content/drive/MyDrive/PoseGraph/tgraphnet:/content/drive/MyDrive/PoseGraph/tgraphnet/src"

# %%
# !echo $PYTHONPATH
# Out:
# /env/python:/content/drive/MyDrive/PoseGraph/tgraphnet:/content/drive/MyDrive/PoseGraph/tgraphnet/src

# %%
# !python3 "models/benchmark.py" --batch_size=32 --mode=both --n_batches=463 --n_measurements=1
# Out:
# TGraphNet(
#   (pre): GCNodeEdgeModule(
#     (gc_node): NodeEdgeConv()
#     (gc_edge): NodeEdgeConv()
#     (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layers): ModuleList(
#     (0): STGConv(
#       (graph_stages): ModuleList(
#         (0): GCResidualBlock(
#           (gc1): GCNodeEdgeModule(
#             (gc_node): NodeEdgeConv()
#             (gc_edge): NodeEdgeConv()
#             (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (gc2): GCNodeEdgeModule(
#             (gc_node): NodeEdgeConv()
#             (gc_edge): NodeEdgeConv()
#             (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
